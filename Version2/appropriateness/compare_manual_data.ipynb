# %%
import pandas as pd
from transformers import BertTokenizer, BertForSequenceClassification
import torch
from sklearn.metrics import classification_report
from collections import Counter

# %%
df = pd.read_csv("manual_labelled.csv")

# %%
df.head()
# Out:
#                topic                                               text  \
# 0  sexual_minorities  У меня есть друзья-пидоры, нормальные вроде ре...
# 1  sexual_minorities  В Израиле вот постоянно гей-парады устраивают,...
# 2  sexual_minorities  Много ли девушек, которым совсем незнаком лесб...
# 3  sexual_minorities  В Британии лечили геев химической кастрацией, ...
# 4  sexual_minorities  Если мужчина возляжет с мужчиной как с женщино...
#
#    inappropriate
# 0              0
# 1              0
# 2              0
# 3              1
# 4              1

# %%
Counter(df.topic)
# Out:
# Counter({'sexual_minorities': 14,
#          'racism': 13,
#          'health_shaming': 12,
#          'body_shaming': 12,
#          'sexism': 11,
#          'politcs': 13,
#          'religion': 10,
#          'social_injustice': 10,
#          'drugs': 10,
#          'weapons': 10,
#          'offline_crime': 10,
#          'online_crime': 11,
#          'gambling': 10,
#          'prostitution': 10,
#          'terrorism': 9,
#          'slavery': 10,
#          'pornography': 8,
#          'suicide': 10})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   topic          193 non-null    object
#  1   text           193 non-null    object
#  2   inappropriate  193 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 4.6+ KB

# %%
def get_model_predictions(model_name, device):
    tokenizer = BertTokenizer.from_pretrained(model_name)
    model = BertForSequenceClassification.from_pretrained(model_name);
    
    tokenized = tokenizer.batch_encode_plus(df.text.tolist(),max_length = 512,
        pad_to_max_length=True,
        truncation=True,
        return_token_type_ids=False)
    tokens_ids,mask = torch.tensor(tokenized['input_ids']),torch.tensor(tokenized['attention_mask']) 
    
    device = torch.device('cuda:{}'.format(device))
    model.to(device);
    
    with torch.no_grad():
        tokens_ids, mask = tokens_ids.to(model.device),mask.to(model.device)
        model_output = model(tokens_ids,mask)
        
    pred = torch.softmax(model_output['logits'], dim = 1)
    
    pred_conf = pred[:,1].cpu().tolist()
    
    pred_round = torch.argmax(pred, dim = 1)
    pred_round = pred_round.cpu().tolist()
    
    del model
    
    return pred_round, pred_conf

# %% [markdown]
# ## Compare models

# %%
mn = 'Skoltech/russian-inappropriate-messages'
our_pred_round, our_pred_conf = get_model_predictions(mn,'0')

# %%
print(classification_report(df.inappropriate.tolist(), our_pred_round))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68        95
#            1       0.69      0.66      0.68        98
#
#     accuracy                           0.68       193
#    macro avg       0.68      0.68      0.68       193
# weighted avg       0.68      0.68      0.68       193

# %%
mn = 'sismetanin/rubert-toxic-pikabu-2ch'
sm_pred_round, sm_pred_conf  = get_model_predictions(mn,'0')
# Out:
# /opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/transformers/tokenization_utils_base.py:2074: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,

# %%
print(classification_report(df.inappropriate.tolist(), sm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.68      0.66        95
#            1       0.67      0.62      0.65        98
#
#     accuracy                           0.65       193
#    macro avg       0.65      0.65      0.65       193
# weighted avg       0.65      0.65      0.65       193

# %% [markdown]
# ## Get statistics

# %%
def print_incorrect(incorr_df, incorr_type):
    print("Should have been {}".format(incorr_type))
    current_topic = ''
    for i,el in incorr_df.iterrows():
        if el['topic'] != current_topic:
            print("="*100)
            print(el['topic'])
            current_topic = el['topic']
        print(el['text'], el['pred_conf'])

# %%
def get_incorrect_statistics(dataframe,predictions, predictions_conf):
    curr_df = dataframe.copy(deep=False)
    curr_df['pred'] = predictions
    curr_df['pred_conf'] = predictions_conf
    incorrect_pred_df = curr_df[curr_df['pred']!=curr_df['inappropriate']]
    incorrect_pred_df = incorrect_pred_df.sort_values(by=['topic'])
    
    incorrect_pred_df_real_1 = incorrect_pred_df[incorrect_pred_df['inappropriate']==1]
    incorrect_pred_df_real_1 = incorrect_pred_df_real_1.sort_values(by=['topic'])
    print_incorrect(incorrect_pred_df_real_1,'inappropriate')
    
    print('\n\n')
    
    incorrect_pred_df_real_0 = incorrect_pred_df[incorrect_pred_df['inappropriate']==0]
    incorrect_pred_df_real_0 = incorrect_pred_df_real_0.sort_values(by=['topic'])
    print_incorrect(incorrect_pred_df_real_0,'OK')
    
    return incorrect_pred_df
    
our_incorr = get_incorrect_statistics(df, our_pred_round, our_pred_conf )
# Out:
# Should have been inappropriate
# ====================================================================================================
# body_shaming
# Да как вообще можно всерьез прислушиваться к мужчине, который красит волосы? 0.006296420935541391
# ====================================================================================================
# gambling
# Продам беспроигрышную схему игры с игровым автоматом, выигрыш каждый раз, минимум 100 рублей. 0.3826906979084015
# пацаны по этому промокоду получите гарантированные выплаты даже за проигранную ставку 0.17374677956104279
# А давайте перекинемся в картишки? На косарь.  0.41370800137519836
# ====================================================================================================
# health_shaming
# У тебя что психическо заболевание или что 0.03317732736468315
# ====================================================================================================
# offline_crime
# Если нужно, могу и по-мужски разобраться, отправить его в больницу месяцев на шесть 0.0017118834657594562
# Избежать уголовки не сложно, главное знать, кому надо предлагать деньги 0.10896723717451096
# ====================================================================================================
# online_crime
# Купить базу телефонных номеров очень просто, поспрашивай на форуме. 0.0051035648211836815
# нашел недавно базу номеров, может пригодиться продаванам 0.0018455003155395389
# Пацаны откопал недавно кряк на новую винду, налетй 0.45179787278175354
# Где бесплатно скачать Гарри Поттера? 0.01582602597773075
# Скажите, а где Лигу справедливости можно скачать? Бесплатно, конечно 0.14823590219020844
# Я купил базу телефонных номеров, если надо, могу поделиться 0.024485604837536812
# ====================================================================================================
# politcs
# Если что, мы можем повторить, как в 45 - и мне кажется, давно пора 0.28134292364120483
# А вы, что, тоже за бункерного деда голосовали? 0.1696271151304245
# ====================================================================================================
# prostitution
# Она точно дама легко повдеения, посмотри на ее повадки и одежду 0.014782913029193878
# Потом пойдём в баню, снимем девочек, в общем, хорошо проведём время 0.029041772708296776
# Когда она говорит "заработала", это и означает - "насосала" 0.06634187698364258
# ====================================================================================================
# racism
# Чёрные люди всё-таки ближе к обезьяне, переходный вид, можно сказать.  0.1637190729379654
# ====================================================================================================
# religion
# Я против того, чтобы допускать мусульман до управления республикой 0.3588051497936249
# ====================================================================================================
# sexism
# Киндер, кюхе, кирхе! Других прав у женщин быть не должно! 0.4595804810523987
# Мужи должен уметь чинить тачки иначе какой он мужик 0.029156174510717392
# Он, как любой мужик, постоянно хочет 0.0034456057474017143
# Все женщины должны рожать детей, в чём иначе их биологическая функция? 0.026165833696722984
# Хорошим математиком женщина все равно быть не может. 0.06147419661283493
# ====================================================================================================
# sexual_minorities
# Если мужчина возляжет с мужчиной как с женщиной, обоих надо забить камнями. По-моему, правильно.  0.4233670234680176
# ====================================================================================================
# slavery
# Нужна печень для пересадки позарез, готов щедро заплатить 0.28375232219696045
# Они вообще бесполезны, им только и место как на галерах привязанных цепями к веслам 0.3898282051086426
# ====================================================================================================
# social_injustice
# Если ты зарабатываешь меньше сотни, ты объективно неудачник 0.4005507826805115
# На какое-либо пособие в России надеяться не приходится. а если и приходится то его ни на что не хватит 0.007180722430348396
# Понанимали всяких птушников, теперь удивляются, почему на проект никто не идёт 0.029761504381895065
# ====================================================================================================
# suicide
# Снотворное - это неэффективно. Гораздо надежнее отравиться мышьяком 0.06762056797742844
# Хочу расстаться с этой изнью, но жалко родителей 0.2542610764503479
#
#
#
# Should have been OK
# ====================================================================================================
# body_shaming
# А то, что у нас половина города ходит в каком-то тряпье и лохмотьях - это разве нормально? 0.6145830750465393
# ====================================================================================================
# drugs
# бросил пить курить аться начал сопртом заниматься 0.6479575634002686
# Он бухает каждую неделю, и здоровее от этого не становится.  0.8759288787841797
# Тот же метамфетамин достаточно опасен, вызывая психологическую зависимость с риском смерти от передоза.  0.8481258749961853
# ====================================================================================================
# health_shaming
# Цивилизованное общество тем и отличается от стада, что проявляет заботу о тех, кто не может позаботиться о себе сам. 0.5496678948402405
# ====================================================================================================
# offline_crime
# За зверское изнасилование данный индивид будет посажен пожизненно в тюрьму 0.986011266708374
# 2021 год в на дворе, а молодых парней в армии всё так же калечат и убивают 0.9827713370323181
# Горе тому, кто пытается унять хулиганов: он может легко познакомиться с финским ножом.. 0.8974019289016724
# ====================================================================================================
# online_crime
# Торренты - действительно удобный способ обмениваться файлами, совершенно не обязательно пиратскими 0.7105610370635986
# ====================================================================================================
# pornography
# В фильме есть сцены половых актов, поэтому он 18+, хоть это и не порно.  0.7065790295600891
# ====================================================================================================
# prostitution
# Словом "шлюха" они называют любую женщину 0.9627084136009216
# На улице красных фонарей можно просто полдоваться на ночных бабочек не нарушающих закон 0.9368705749511719
# Есть страны где быть продажной жензиной законно 0.9929789900779724
# ====================================================================================================
# racism
# Судить о людях по цвету кожи это отвратительнои  непримелемо 0.5951851010322571
# Те, кого ты называешь чурками и хачами, имели цивилизацию намного раньше нашей.  0.9948878884315491
# ====================================================================================================
# religion
# Буддисты вполне мирно относятся к инвоерцами 0.7103650569915771
# ====================================================================================================
# sexual_minorities
# У меня есть друзья-пидоры, нормальные вроде ребята.  0.9932920932769775
# В Израиле вот постоянно гей-парады устраивают, а у нас бы за такое жестоко покарали.  0.9760825037956238
# Мне нравится общаться с гееватыми ребятами, они довольно милые 0.733661413192749
# Гомосекусуалисты как правило не выбирают кем быть 0.8948656320571899
# Много ли девушек, которым совсем незнаком лесбийский секс? 0.734314501285553
# ====================================================================================================
# slavery
# Органы могут быть переданы реципиенту только через официальные каналы на бесплатной основе 0.6657606363296509
# Рабство является крайне неэффективным, поэтому оно себя изжило 0.7138856649398804
# Даже в Европе еще существует рабство - можно попасть в рабство за долги или быть проданным кем-то. 0.5858307480812073
# ====================================================================================================
# suicide
# Как правило данные индивиды не ограничиваются обычным самоубицством, они сплочаются в группы и наирают сторонников, распространяя эту заразы в массы 0.9435515999794006
# Выпиливаться - так они называю самоубийство 0.9460197687149048
# Большое количество юношей и девушек каждый год завершают жизнь самоубийством 0.9751723408699036
# Попытка самоубийства может быть реальной или демонстративной 0.8839051127433777
# ====================================================================================================
# weapons
# Фауст патрон был страным сном в дни захвата берлина 0.7295379638671875

# %%
sm_incorr = get_incorrect_statistics(df, sm_pred_round, sm_pred_conf )
# Out:
# Should have been inappropriate
# ====================================================================================================
# body_shaming
# Да как вообще можно всерьез прислушиваться к мужчине, который красит волосы? 0.013123086653649807
# ====================================================================================================
# drugs
# Айкос не такие вредные как обыные сиги, но мне все равно буду дальше так же дымить 0.003815141273662448
# Да мне даже в десять лет водку продавали. 0.0029016879852861166
# Многие выдающиеся личности принимали вещества, и ничего, долго жили и продолжали творить, поэтому не верьте тем, кто вас запугивает.  0.058852940797805786
# Так-то трава весьма безопасная, если не каждый день её употреблять.  0.002845851005986333
# ====================================================================================================
# gambling
# Продам беспроигрышную схему игры с игровым автоматом, выигрыш каждый раз, минимум 100 рублей. 0.00466263247653842
# На тотализаторах реально можно заработать, я хорошо поднялся на ставках на футбольные матчи, рекомендую.  0.003003397723659873
# ====================================================================================================
# health_shaming
# Не понимаю, почему не разрешают эвтаназию для инвалидов, всё ж лучше, чем жить и мучаться 0.04269208014011383
# ====================================================================================================
# offline_crime
# Избежать уголовки не сложно, главное знать, кому надо предлагать деньги 0.0032277635764330626
# Если нужно, могу и по-мужски разобраться, отправить его в больницу месяцев на шесть 0.004831844475120306
# ====================================================================================================
# online_crime
# Я купил базу телефонных номеров, если надо, могу поделиться 0.0022611485328525305
# Где бесплатно скачать Гарри Поттера? 0.0936572328209877
# Скажите, а где Лигу справедливости можно скачать? Бесплатно, конечно 0.0025464054197072983
# нашел недавно базу номеров, может пригодиться продаванам 0.0028762563597410917
# Купить базу телефонных номеров очень просто, поспрашивай на форуме. 0.003286713967099786
# ====================================================================================================
# politcs
# Если что, мы можем повторить, как в 45 - и мне кажется, давно пора 0.0024272119626402855
# Американцы сами организовали 11 сентября, чтоб потом был повод бомбить Ирак. 0.015399783849716187
# ====================================================================================================
# pornography
# Кто пробовал двойное проникновение? как ощущения? 0.02107347548007965
# ====================================================================================================
# prostitution
# Когда она говорит "заработала", это и означает - "насосала" 0.0023927800357341766
# Можно нарыть девочек и пойти туснуть где-нибудь заородоюм Выйдет недорого 0.1439526379108429
# Потом пойдём в баню, снимем девочек, в общем, хорошо проведём время 0.013784898445010185
# ====================================================================================================
# racism
# Всех черных не стоит брать на приличную работу, они будут только позорить компанию 0.44481179118156433
# ====================================================================================================
# sexism
# Все женщины должны рожать детей, в чём иначе их биологическая функция? 0.3169916868209839
# Хорошим математиком женщина все равно быть не может. 0.2788255214691162
# ====================================================================================================
# slavery
# Нужна печень для пересадки позарез, готов щедро заплатить 0.010799325071275234
# Они вообще бесполезны, им только и место как на галерах привязанных цепями к веслам 0.21488159894943237
# А сколько реально можно заработать, если продать почку? 0.002950998954474926
# ====================================================================================================
# social_injustice
# Понанимали всяких птушников, теперь удивляются, почему на проект никто не идёт 0.42709293961524963
# На какое-либо пособие в России надеяться не приходится. а если и приходится то его ни на что не хватит 0.0026606377214193344
# Пособия по безроаботицы тебе не хватит даже на то чтоб штаны поддержать 0.12602752447128296
# ====================================================================================================
# suicide
# Как бы мне выпилиться чтобы быстро и небольно? Прыгать с крыши все же страшновато 0.006948514841496944
# Снотворное - это неэффективно. Гораздо надежнее отравиться мышьяком 0.0037790362257510424
# ====================================================================================================
# terrorism
# При необходимости, взрывчатое вещество можно сделать из обычного стирального порошка, набить пояс гвоздями, и можно идти взрываться.  0.003295477945357561
# А почему бы просто не взорвать Пентагон с концами? 0.09179907292127609
# ====================================================================================================
# weapons
# Какие рекомендуете способы провезти пистолет в самолёте? Очень надо! 0.00815795361995697
# Купить пистолет - не проблема, если знаешь где. 0.003812720300629735
# У меня дома хранится калаш, если вдруг что могу немнжко попугать соседей а если надо и стрельнуть 0.02460172399878502
#
#
#
# Should have been OK
# ====================================================================================================
# body_shaming
# Согласно опросам, блондины производят лучшее впечатление на собеседованиях, чем брюнеты 0.5448997020721436
# Мне кажется, что украинские девушки симпатичнее русских, но это моё личное мнение.  0.9605866074562073
# ====================================================================================================
# drugs
# Никотин - мощный нейростимулятор. 0.9922492504119873
# Он бухает каждую неделю, и здоровее от этого не становится.  0.9534845352172852
# бросил пить курить аться начал сопртом заниматься 0.809846818447113
# ====================================================================================================
# gambling
# Лудомания это страшная болезнь которая разрушает человеческие жизни 0.9892001152038574
# ====================================================================================================
# health_shaming
# В России десятки тысяч людей с синдромом Дауна 0.9809509515762329
# ====================================================================================================
# offline_crime
# За зверское изнасилование данный индивид будет посажен пожизненно в тюрьму 0.9521626234054565
# Горе тому, кто пытается унять хулиганов: он может легко познакомиться с финским ножом.. 0.9280371069908142
# недавно вышел сериал о Чикатило - известном маньяке 0.9217090606689453
# ====================================================================================================
# politcs
# Вопросы о принадлежности территорий типа карабазов крымов и прочих алясок - это довльное скользкая тема, давайт ене будем ее обсужадть 0.6723739504814148
# В Вашингтоне сторонники Дональда Трампа устроили штурм Белого дома 0.886406421661377
# ====================================================================================================
# prostitution
# Словом "шлюха" они называют любую женщину 0.9894027709960938
# ====================================================================================================
# racism
# В Москве живет около 200 тысяч таджиков 0.5720030069351196
# Негр - нормальное русское слово, а Нигер - вообще страна в африке.  0.8952882885932922
# Судить о людях по цвету кожи это отвратительнои  непримелемо 0.8379619121551514
# Скажем нет расизму! 0.6950402855873108
# Те, кого ты называешь чурками и хачами, имели цивилизацию намного раньше нашей.  0.992361307144165
# ====================================================================================================
# religion
# Свидетели Иеговы - секта, запрещенная на территории России 0.9877814054489136
# Буддисты вполне мирно относятся к инвоерцами 0.987432599067688
# А вам-то какое дело, что я не верю ни в Аллаха, ни в Иисуса? 0.9380888342857361
# ====================================================================================================
# sexism
# Мужики почти все ушли на войну, а бабы остались смотреть за хозяйством.  0.9887166023254395
# ====================================================================================================
# sexual_minorities
# У меня есть друзья-пидоры, нормальные вроде ребята.  0.9838302731513977
# Мне нравится общаться с гееватыми ребятами, они довольно милые 0.8424025774002075
# Гомосексуализм присущ не только людям, но и практически всем видам животных. 0.5351868271827698
# Гомосекусуалисты как правило не выбирают кем быть 0.9791997075080872
# ====================================================================================================
# suicide
# Если ты хочешь выпилиться, даже и не думай об этом. Не стоит принимать необоснованных решений.  0.6585315465927124
# Выпиливаться - так они называю самоубийство 0.771350622177124
# ====================================================================================================
# terrorism
# Данный пост является призывмо к войне и должен быть удален 0.8790149092674255
# ====================================================================================================
# weapons
# Автомат ккалшникова -великое изобретение великого советского человека 0.929323673248291

# %% [markdown]
# ## Compare topics

# %%
Counter(our_incorr.topic.tolist()).most_common(100)
# Out:
# [('online_crime', 7),
#  ('prostitution', 6),
#  ('sexual_minorities', 6),
#  ('suicide', 6),
#  ('offline_crime', 5),
#  ('sexism', 5),
#  ('slavery', 5),
#  ('drugs', 3),
#  ('gambling', 3),
#  ('racism', 3),
#  ('social_injustice', 3),
#  ('body_shaming', 2),
#  ('health_shaming', 2),
#  ('politcs', 2),
#  ('religion', 2),
#  ('pornography', 1),
#  ('weapons', 1)]

# %%
len(Counter(our_incorr.topic.tolist()))
# Out:
# 17

# %%
Counter(sm_incorr.topic.tolist()).most_common(100)
# Out:
# [('drugs', 7),
#  ('racism', 6),
#  ('offline_crime', 5),
#  ('online_crime', 5),
#  ('politcs', 4),
#  ('prostitution', 4),
#  ('sexual_minorities', 4),
#  ('suicide', 4),
#  ('weapons', 4),
#  ('body_shaming', 3),
#  ('gambling', 3),
#  ('religion', 3),
#  ('sexism', 3),
#  ('slavery', 3),
#  ('social_injustice', 3),
#  ('terrorism', 3),
#  ('health_shaming', 2),
#  ('pornography', 1)]

# %%
len(Counter(sm_incorr.topic.tolist()))
# Out:
# 18
